# %%
from langchain_community.tools.tavily_search import TavilySearchResults
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_14112\1904316797.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools.tavily_search import TavilySearchResults

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool=TavilySearchResults(max=2)
results=tool.invoke({"query":'fifa 2026 final match teams?'})
results
# Out:
# [{'title': 'FIFA World Cup 2026 final | All you need to know',
#   'url': 'https://www.fifa.com/en/tournaments/mens/worldcup/canadamexicousa2026/articles/final-live-watch-teams-tickets',
# ...
